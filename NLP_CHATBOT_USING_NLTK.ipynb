# %% [markdown]
# <a href="https://colab.research.google.com/github/Manikanta-23-ai/NATURAL-LANGUAGE-PROPROSSING-PROJECTS/blob/main/NLP_CHATBOT_USING_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
